# %%
# !nvidia-smi
# Out:
# Mon Sep 23 17:53:46 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 457.49       Driver Version: 457.49       CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce MX250      WDDM  | 00000000:02:00.0 Off |                  N/A |
# | N/A   44C    P0    N/A /  N/A |     64MiB /  2048MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\RAGIRI CHANDU\Desktop\ArmingYolo

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.99  Python-3.12.6 torch-2.4.1+cpu CPU (Intel Core(TM) i5-10210U 1.60GHz)
# Setup complete  (8 CPUs, 7.8 GB RAM, 207.1/237.2 GB disk)

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='/kaggle/input/weapons1/weaponss/data.yaml', epochs=400, patience=0) 
# model.save('/kaggle/working/weaponDetector.h5')
# Out:
# Ultralytics YOLOv8.2.99  Python-3.12.6 torch-2.4.1+cpu CPU (Intel Core(TM) i5-10210U 1.60GHz)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=/kaggle/input/weapons1/weaponss/data.yaml, epochs=400, time=None, patience=0, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=C:\Users\RAGIRI CHANDU\runs\detect\train2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py:557, in BaseTrainer.get_dataset(self)
#     551 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     552     "detect",
#     553     "segment",
#     554     "pose",
#     555     "obb",
#     556 }:
# --> 557     data = check_det_dataset(self.args.data)
#     558     if "yaml_file" in data:
#
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\data\utils.py:268, in check_det_dataset(dataset, autodownload)
#     254 """
#     255 Download, verify, and/or unzip a dataset if not found locally.
#     256
#    (...)
#     266     (dict): Parsed dataset information and paths.
#     267 """
# --> 268 file = check_file(dataset)
#     270 # Download (optional)
#
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\utils\checks.py:517, in check_file(file, suffix, download, download_dir, hard)
#     516 if not files and hard:
# --> 517     raise FileNotFoundError(f"'{file}' does not exist")
#     518 elif len(files) > 1 and hard:
#
# FileNotFoundError: '/kaggle/input/weapons1/weaponss/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 5
#       2 model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
#       4 # Use the model
# ----> 5 results = model.train(data='/kaggle/input/weapons1/weaponss/data.yaml', epochs=400, patience=0)
#       6 # model.save('/kaggle/working/weaponDetector.h5')
#
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:797, in Model.train(self, trainer, **kwargs)
#     794 if args.get("resume"):
#     795     args["resume"] = self.ckpt_path
# --> 797 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     798 if not args.get("resume"):  # manually set model only if not resuming
#     799     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py:133, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     131 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     132 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 133     self.trainset, self.testset = self.get_dataset()
#     134 self.ema = None
#     136 # Optimization utils init
#
# File c:\Users\RAGIRI CHANDU\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py:561, in BaseTrainer.get_dataset(self)
#     559             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     560 except Exception as e:
# --> 561     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     562 self.data = data
#     563 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset '/kaggle/input/weapons1/weaponss/data.yaml' error  '/kaggle/input/weapons1/weaponss/data.yaml' does not exist

# %%
# !zip -r file.zip /kaggle/working
# Out:
# 	zip warning: name not matched: /kaggle/working
#
# zip error: Nothing to do! (try: zip -r file.zip . -i /kaggle/working)

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
